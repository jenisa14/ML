3 MB/s eta 0:00:10
#    ---------------------------- ----------- 81.8/113.8 MB 3.3 MB/s eta 0:00:10
#    ----------------------------- ---------- 82.8/113.8 MB 3.3 MB/s eta 0:00:10
#    ----------------------------- ---------- 83.6/113.8 MB 3.3 MB/s eta 0:00:10
#    ----------------------------- ---------- 84.7/113.8 MB 3.3 MB/s eta 0:00:09
#    ------------------------------ --------- 85.5/113.8 MB 3.3 MB/s eta 0:00:09
#    ------------------------------ --------- 86.5/113.8 MB 3.3 MB/s eta 0:00:09
#    ------------------------------ --------- 87.3/113.8 MB 3.3 MB/s eta 0:00:08
#    ------------------------------- -------- 88.6/113.8 MB 3.4 MB/s eta 0:00:08
#    ------------------------------- -------- 89.7/113.8 MB 3.4 MB/s eta 0:00:08
#    ------------------------------- -------- 90.4/113.8 MB 3.4 MB/s eta 0:00:07
#    -------------------------------- ------- 91.5/113.8 MB 3.4 MB/s eta 0:00:07
#    -------------------------------- ------- 92.0/113.8 MB 3.4 MB/s eta 0:00:07
#    -------------------------------- ------- 92.5/113.8 MB 3.4 MB/s eta 0:00:07
#    -------------------------------- ------- 93.1/113.8 MB 3.4 MB/s eta 0:00:07
#    -------------------------------- ------- 93.8/113.8 MB 3.4 MB/s eta 0:00:06
#    --------------------------------- ------ 94.6/113.8 MB 3.4 MB/s eta 0:00:06
#    --------------------------------- ------ 95.2/113.8 MB 3.4 MB/s eta 0:00:06
#    --------------------------------- ------ 95.9/113.8 MB 3.4 MB/s eta 0:00:06
#    ---------------------------------- ----- 97.3/113.8 MB 3.4 MB/s eta 0:00:05
#    ---------------------------------- ----- 98.6/113.8 MB 3.4 MB/s eta 0:00:05
#    ----------------------------------- ---- 99.6/113.8 MB 3.4 MB/s eta 0:00:05
#    ----------------------------------- ---- 100.7/113.8 MB 3.4 MB/s eta 0:00:04
#    ----------------------------------- ---- 101.7/113.8 MB 3.4 MB/s eta 0:00:04
#    ------------------------------------ --- 102.8/113.8 MB 3.4 MB/s eta 0:00:04
#    ------------------------------------ --- 104.1/113.8 MB 3.5 MB/s eta 0:00:03
#    ------------------------------------- -- 105.4/113.8 MB 3.5 MB/s eta 0:00:03
#    ------------------------------------- -- 106.4/113.8 MB 3.5 MB/s eta 0:00:03
#    ------------------------------------- -- 107.7/113.8 MB 3.6 MB/s eta 0:00:02
#    -------------------------------------- - 109.1/113.8 MB 3.6 MB/s eta 0:00:02
#    -------------------------------------- - 109.8/113.8 MB 3.6 MB/s eta 0:00:02
#    ---------------------------------------  111.1/113.8 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  112.5/113.8 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------  113.5/113.8 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------  113.5/113.8 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------- 113.8/113.8 MB 3.7 MB/s eta 0:00:00
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    ------ --------------------------------- 1.0/6.3 MB 6.3 MB/s eta 0:00:01
#    -------------- ------------------------- 2.4/6.3 MB 5.8 MB/s eta 0:00:01
#    ----------------------- ---------------- 3.7/6.3 MB 5.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 4.7/6.3 MB 5.6 MB/s eta 0:00:01
#    -------------------------------------- - 6.0/6.3 MB 5.8 MB/s eta 0:00:01
#    ---------------------------------------- 6.3/6.3 MB 5.6 MB/s eta 0:00:00
# Installing collected packages: sympy, torch
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.13.2
#     Uninstalling sympy-1.13.2:
#       Successfully uninstalled sympy-1.13.2
# Successfully installed sympy-1.14.0 torch-2.10.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Task 1: GPU/Device Agnostic Code
# **Goal:** Write code that runs on CPU, CUDA, or MPS (Mac) automatically.

# %%
device = 'cuda' if torch.cuda.is_available() else 'mps' if torch.backends.mps.is_available() else 'cpu'
print(f'Using device: {device}')


sample_input = torch.randn(1, 10).to(device)
type(sample_input)

# %%
sample_input

# %% [markdown]
# ## Section 2: MNIST Project
# Step 1: What is MNIST & Downloading Data
#
# Concept: MNIST is the "Hello World" of Machine Learning. It contains 70,000 images of handwritten digits (0-9).
#
# The Goal: Teach the computer to look at a grid of pixels and say "That is a 7".
#
# The Data: Each image is grayscale and exactly 28×28

# %%
from torchvision import datasets
from torchvision.transforms import ToTensor

# %%
training_data = datasets.MNIST(
    root="data",
    train=True,
    download=True,
    transform=ToTensor()
)
# transform=ToTensor() converts the image (0-255) to a Torch Tensor (0.0-1.0)

# %%
test_data = datasets.FashionMNIST(
    root="data",
    train=False,
    download=True,
    transform=ToTensor()
)

# %% [markdown]
# ## Visualizing One Image & Understanding Shapes

# %%
len(training_data)

# %%
len(test_data)

# %%
img, label = training_data[100]

# %%
img.shape

# %%
img

# %%
img.squeeze().shape

# %% [markdown]
# ## Display one Image in MatplotLib

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img.squeeze(), cmap="gray")
plt.title(f"This is a number {label}")
plt.show()

# %% [markdown]
# # Calculation for the Input Layer

# %% [markdown]
# Concept: We are building a Linear (Feed-Forward) Network,
#
# A Linear Layer consists of neurons in a single vertical line.
#
# Our image is a square grid (28×28).
#
# The Division: We must "cut" the image row by row and stack them into one long line.
#
# The Calculation:
#
# Height×Width=Total Input Features
# 28×28=784
# So, our Input Layer must have 784 neurons.

# %%
img, label = training_data[1]

# %%
img.squeeze().shape

# %% [markdown]
# ## The Architecture (1 Input, 1 Hidden, 1 Output
# The Concept: We will build the simplest standard network.
#
# Input Layer (784): Receives the pixels.
#
# Hidden Layer (128): The "brain" that learns shapes (loops, lines). We pick 128 because it's enough to learn but not too big.
#
# Output Layer (10): The final decision. We have 10 digits (0-9), so we need 10 output scores.

# %%
import torch.nn as nn

class SimpleNet(nn.Module):
    def __init__(self):
        super().__init__()
        self.flatten = nn.Flatten()
        
        self.layers = nn.Sequential(
            nn.Linear(784, 128), 
            nn.ReLU(),# Activation 
            nn.Linear(128, 10)
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.layers(x)
        return logits

model = SimpleNet()
print(model)

# %% [markdown]
# ## Understanding Batch Size (The Stack)
#
# The Concept: Think of the model like a teacher grading exams.
#
# Batch Size = 1: The teacher grades 1 exam, updates the grade book, then picks up the next exam. (Too slow).
#
# Batch Size = 64: The teacher picks up a stack of 64 exams, grades them all at once, and updates the grade book one time for the whole stack. (Much faster).
#
# We use DataLoader to create these "stacks" for us.

# %%
from torch.utils.data import DataLoader

# Create stacks
train_loader = DataLoader(training_data, batch_size=64, shuffle=True)
test_loader = DataLoader(test_data, batch_size=64, shuffle=True)

print(len(train_loader),"--",len(test_loader))

# %% [markdown]
# ## The Training Loop

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
loss_fn = nn.CrossEntropyLoss()

# %%
def train(num_epochs):
    model.train()
    
    for epoch in range(num_epochs):
        print(f"\n--- Epoch {epoch + 1}/{num_epochs} ---")
        
        for batch_No, (data, target) in enumerate(train_loader):
            
            output = model(data)
            
            loss = loss_fn(output, target)
            
            # Backpropagation
            optimizer.zero_grad()  # Clear old calculations
            loss.backward()        # Calculate gradients
            optimizer.step()       # Update weights
            
            if batch_No % 100 == 0:
                print(f"Batch {batch_No}: Loss = {loss.item():.4f}")
        
        print(f"Epoch {epoch + 1} completed!")

# Run training

# %%
train(5)

# %%
def test():
    model.eval() 
    correct = 0
    
    with torch.no_grad(): 
        for data, target in test_loader:
            output = model(data)
            
            prediction = output.argmax(dim=1) 
            
            correct += (prediction == target).sum().item()

    accuracy = correct / len(test_loader.dataset)
    print(f"Test Accuracy: {accuracy:.1%}")

test()

# %%
def test():
    model.eval() 
    correct = 0
    
    with torch.no_grad(): 
        for data, target in train_loader:
            output = model(data)
            
            prediction = output.argmax(dim=1) 
            
            correct += (prediction == target).sum().item()

    accuracy = correct / len(train_loader.dataset)
    print(f"Test Accuracy: {accuracy:.1%}")

test()
