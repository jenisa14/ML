# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>Machine Learning - 2301CS621</b></center>
#
# <center><b><h1>Lab - 10 </b></center>
# <center><b><h5>K-means, K-Medoids</b></center>
# <pre>

# %% [markdown]
# # Step 1: Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %% [markdown]
# # Step 2: Load the Dataset
# Load Given dataset -  StudentsPerformance.csv

# %%
df = pd.read_csv("StudentsPerformance.csv");

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [1000 rows x 8 columns]

# %% [markdown]
# # Step 3: Data Overview
# In this step, we examine the dataset structure, summary statistics, and check for missing values.

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
df.info
# Out:
# <bound method DataFrame.info of      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [1000 rows x 8 columns]>

# %% [markdown]
# # Step 4: Display PairPlot

# %%
sns.pairplot(df)

# %% [markdown]
# # Step 5: Correlation heatmap

# %%
plt.figure(figsize=(8,6))
numeric_df = df.select_dtypes(include=[np.number])

# coolwarm
sns.heatmap(numeric_df.corr(),annot=True,cmap='coolwarm',fmt=".2f",)
plt.title("correlation matrix")
plt.show()

# %% [markdown]
# # Step 6: Distribution of numerical features

# %%
# plt.plot(numeric_df)
# numeric_df.plot(kind="hist",bins=10)

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,3,1)
sns.histplot(df['math score'],kde =True,color='green')
plt.title('Maths score destribution')


plt.subplot(1,3,2)
sns.histplot(df['reading score'],kde =True,color='blue')
plt.title('Reading score destribution')


plt.subplot(1,3,3)
sns.histplot(df['writing score'],kde =True,color='red')
plt.title('Writing score destribution')
# Out:
# Text(0.5, 1.0, 'Writing score destribution')

# %% [markdown]
# # Step 7: Apply StandardScaler

# %%
# only for practice - > all columns have same range 
# numeric_df = df.select_dtypes(include=[np.number])
scaler = StandardScaler()
scaled_data = scaler.fit_transform(numeric_df)
scaler
# Out:
# StandardScaler()

# %%
scaled_data
# Out:
# array([[ 0.39002351,  0.19399858,  0.39149181],
#        [ 0.19207553,  1.42747598,  1.31326868],
#        [ 1.57771141,  1.77010859,  1.64247471],
#        ...,
#        [-0.46775108,  0.12547206, -0.20107904],
#        [ 0.12609287,  0.60515772,  0.58901542],
#        [ 0.71993682,  1.15336989,  1.18158627]])

# %% [markdown]
# # Step 8: Elbow method to find optimal k

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
# wcss - within-cluster sum of square
wcss = []
k_range = range(1, 11)

for k in k_range:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(scaled_data)
    wcss.append(kmeans.inertia_)

# Plot Elbow graph
plt.figure(figsize=(10, 6))
plt.plot(k_range, wcss, marker='o', linestyle='--')
plt.title('Elbow Method')
plt.xlabel('Number of clusters (k)')
plt.ylabel('WCSS')
plt.show()

print(wcss)
# Out:
# D:\DU\SEM-5\Python_setup\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# D:\DU\SEM-5\Python_setup\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# D:\DU\SEM-5\Python_setup\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# D:\DU\SEM-5\Python_setup\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# D:\DU\SEM-5\Python_setup\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# D:\DU\SEM-5\Python_setup\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# D:\DU\SEM-5\Python_setup\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# D:\DU\SEM-5\Python_setup\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# D:\DU\SEM-5\Python_setup\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# D:\DU\SEM-5\Python_setup\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# [3000.0000000000005, 1253.857114450882, 788.3656838915332, 604.9212390130839, 492.95066485513547, 432.71583624798603, 383.1368293631918, 340.8342066300557, 304.34863911788415, 274.2000202706408]

# %% [markdown]
# # Step 9:Based on the elbow plot, choose an appropriate k value (e.g., k=3)

# %%
optimal_k = 3
kmeans = KMeans(n_clusters=optimal_k,random_state=42,n_init=10,)
y_kmeans = kmeans.fit_predict(scaled_data,)
df['Cluster_KMeans'] = y_kmeans
# Out:
# D:\DU\SEM-5\Python_setup\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(

# %% [markdown]
# # Step 10: Print Cluster Center

# %%
print("Cluster Centers (Scaled):")
print(kmeans.cluster_centers_)
print("\nCluster centers(Original Scale):")
print(scaler.inverse_transform(kmeans.cluster_centers_))
# Out:
# Cluster Centers (Scaled):
# [[-0.04951336 -0.04870596 -0.01529686]
#  [-1.18720058 -1.26762535 -1.28838441]
#  [ 1.03099793  1.09485536  1.06358515]]
#
# Cluster centers(Original Scale):
# [[65.33860045 68.45823928 67.82167043]
#  [48.09638554 50.67068273 48.48594378]
#  [81.71428571 85.1461039  84.20779221]]

# %% [markdown]
# # Step 11: Plot Cluster

# %%
# same as 12th

# %% [markdown]
# # Step 12:Analyze clusters

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x=scaled_data[:,0],y=scaled_data[:,1],hue=y_kmeans,palette='viridis',s=100,)

plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1],
           s=300,c='red',marker='X',label='Centroids')

plt.title(f'K-Means Clustering (k={optimal_k})')
plt.xlabel('Math Score(Scaled)')
plt.ylabel('Reading Score(Scaled)')
plt.legend()
plt.show()

# %% [markdown]
# # Step 13: Perform K-Medoids

# %%
# !pip install scikit-learn-extra
# Out:
# Collecting scikit-learn-extra
#   Using cached scikit-learn-extra-0.3.0.tar.gz (818 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy>=1.13.3 in d:\du\sem-5\python_setup\lib\site-packages (from scikit-learn-extra) (1.26.4)
# Requirement already satisfied: scipy>=0.19.1 in d:\du\sem-5\python_setup\lib\site-packages (from scikit-learn-extra) (1.13.1)
# Requirement already satisfied: scikit-learn>=0.23.0 in d:\du\sem-5\python_setup\lib\site-packages (from scikit-learn-extra) (1.5.1)
# Requirement already satisfied: joblib>=1.2.0 in d:\du\sem-5\python_setup\lib\site-packages (from scikit-learn>=0.23.0->scikit-learn-extra) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\du\sem-5\python_setup\lib\site-packages (from scikit-learn>=0.23.0->scikit-learn-extra) (3.5.0)
# Building wheels for collected packages: scikit-learn-extra
#   Building wheel for scikit-learn-extra (pyproject.toml): started
#   Building wheel for scikit-learn-extra (pyproject.toml): finished with status 'error'
# Failed to build scikit-learn-extra
#   error: subprocess-exited-with-error
#
#   Building wheel for scikit-learn-extra (pyproject.toml) did not run successfully.
#   exit code: 1
#
#   [77 lines of output]
#   C:\Users\Dhaval Vasani\AppData\Local\Temp\pip-build-env-xml634f8\overlay\Lib\site-packages\setuptools\dist.py:599: SetuptoolsDeprecationWarning: Invalid dash-separated key 'description-file' in 'metadata' (setup.cfg), please use the underscore name 'description_file' instead.
#   !!
#
#           ********************************************************************************
#           Usage of dash-separated 'description-file' will not be supported in future
#           versions. Please use the underscore name 'description_file' instead.
#           (Affected: scikit-learn-extra).
#
#           Available configuration options are listed in:
#           https://setuptools.pypa.io/en/latest/userguide/declarative_config.html
#
#           By 2026-Mar-03, you need to update your project and remove deprecated calls
#           or your builds will no longer be supported.
#
#           See https://github.com/pypa/setuptools/discussions/5011 for details.
#           ********************************************************************************
#
#   !!
#     opt = self._enforce_underscore(opt, section)
#   C:\Users\Dhaval Vasani\AppData\Local\Temp\pip-build-env-xml634f8\overlay\Lib\site-packages\setuptools\dist.py:765: SetuptoolsDeprecationWarning: License classifiers are deprecated.
#   !!
#
#           ********************************************************************************
#           Please consider removing the following classifiers in favor of a SPDX license expression:
#
#           License :: OSI Approved
#
#           See https://packaging.python.org/en/latest/guides/writing-pyproject-toml/#license for details.
#           ********************************************************************************
#
#   !!
#     self._finalize_license_expression()
#   running bdist_wheel
#   running build
#   running build_py
#   creating build\lib.win-amd64-cpython-312\benchmarks
#   copying benchmarks\bench_rbfsampler_fastfood.py -> build\lib.win-amd64-cpython-312\benchmarks
#   copying benchmarks\__init__.py -> build\lib.win-amd64-cpython-312\benchmarks
#   creating build\lib.win-amd64-cpython-312\sklearn_extra
#   copying sklearn_extra\_version.py -> build\lib.win-amd64-cpython-312\sklearn_extra
#   copying sklearn_extra\__init__.py -> build\lib.win-amd64-cpython-312\sklearn_extra
#   creating build\lib.win-amd64-cpython-312\benchmarks\_bench
#   copying benchmarks\_bench\eigenpro_plot_mnist.py -> build\lib.win-amd64-cpython-312\benchmarks\_bench
#   copying benchmarks\_bench\eigenpro_plot_noisy_mnist.py -> build\lib.win-amd64-cpython-312\benchmarks\_bench
#   copying benchmarks\_bench\eigenpro_plot_synthetic.py -> build\lib.win-amd64-cpython-312\benchmarks\_bench
#   copying benchmarks\_bench\robust_plot_synthetic.py -> build\lib.win-amd64-cpython-312\benchmarks\_bench
#   copying benchmarks\_bench\__init__.py -> build\lib.win-amd64-cpython-312\benchmarks\_bench
#   creating build\lib.win-amd64-cpython-312\sklearn_extra\cluster
#   copying sklearn_extra\cluster\_commonnn.py -> build\lib.win-amd64-cpython-312\sklearn_extra\cluster
#   copying sklearn_extra\cluster\_k_medoids.py -> build\lib.win-amd64-cpython-312\sklearn_extra\cluster
#   copying sklearn_extra\cluster\__init__.py -> build\lib.win-amd64-cpython-312\sklearn_extra\cluster
#   creating build\lib.win-amd64-cpython-312\sklearn_extra\kernel_approximation
#   copying sklearn_extra\kernel_approximation\test_fastfood.py -> build\lib.win-amd64-cpython-312\sklearn_extra\kernel_approximation
#   copying sklearn_extra\kernel_approximation\_fastfood.py -> build\lib.win-amd64-cpython-312\sklearn_extra\kernel_approximation
#   copying sklearn_extra\kernel_approximation\__init__.py -> build\lib.win-amd64-cpython-312\sklearn_extra\kernel_approximation
#   creating build\lib.win-amd64-cpython-312\sklearn_extra\kernel_methods
#   copying sklearn_extra\kernel_methods\_eigenpro.py -> build\lib.win-amd64-cpython-312\sklearn_extra\kernel_methods
#   copying sklearn_extra\kernel_methods\__init__.py -> build\lib.win-amd64-cpython-312\sklearn_extra\kernel_methods
#   creating build\lib.win-amd64-cpython-312\sklearn_extra\robust
#   copying sklearn_extra\robust\mean_estimators.py -> build\lib.win-amd64-cpython-312\sklearn_extra\robust
#   copying sklearn_extra\robust\robust_weighted_estimator.py -> build\lib.win-amd64-cpython-312\sklearn_extra\robust
#   copying sklearn_extra\robust\__init__.py -> build\lib.win-amd64-cpython-312\sklearn_extra\robust
#   creating build\lib.win-amd64-cpython-312\sklearn_extra\tests
#   copying sklearn_extra\tests\test_common.py -> build\lib.win-amd64-cpython-312\sklearn_extra\tests
#   copying sklearn_extra\tests\__init__.py -> build\lib.win-amd64-cpython-312\sklearn_extra\tests
#   creating build\lib.win-amd64-cpython-312\sklearn_extra\cluster\tests
#   copying sklearn_extra\cluster\tests\test_commonnn.py -> build\lib.win-amd64-cpython-312\sklearn_extra\cluster\tests
#   copying sklearn_extra\cluster\tests\test_k_medoids.py -> build\lib.win-amd64-cpython-312\sklearn_extra\cluster\tests
#   copying sklearn_extra\cluster\tests\__init__.py -> build\lib.win-amd64-cpython-312\sklearn_extra\cluster\tests
#   creating build\lib.win-amd64-cpython-312\sklearn_extra\kernel_approximation\tests
#   copying sklearn_extra\kernel_approximation\tests\__init__.py -> build\lib.win-amd64-cpython-312\sklearn_extra\kernel_approximation\tests
#   creating build\lib.win-amd64-cpython-312\sklearn_extra\kernel_methods\tests
#   copying sklearn_extra\kernel_methods\tests\test_eigenpro.py -> build\lib.win-amd64-cpython-312\sklearn_extra\kernel_methods\tests
#   copying sklearn_extra\kernel_methods\tests\__init__.py -> build\lib.win-amd64-cpython-312\sklearn_extra\kernel_methods\tests
#   running build_ext
#   building 'sklearn_extra.utils._cyfht' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for scikit-learn-extra
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (scikit-learn-extra)

# %%
from sklearn.extra.cluster import KMedoids
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 from sklearn.extra.cluster import KMedoids
#
# ModuleNotFoundError: No module named 'sklearn.extra'

# %% [markdown]
# # Step:14 Comparison of K-means and K-medoids Clusters

# %%
kmedoids(n_clusters=optimal_k,random_state=42,method='pam')
y_kmedoids=kmedoids.fit_predict(scaled_data)

df['Cluster_KMedoids']=y_kmedoids
print("k-Medoids fitted successfully.")

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x=scaled_data[:,0],y=scaled_data[:])

plt.scatter(kmedoids.cluster_centers_[:,0],kmedoids.cluster_centers_[:,1],s=300,c='red',marker='X',label='Medoids')
plt.title(f'k-medoids clustering (k={optimal})')

# %% [markdown]
# # Step: 15 | USE KMEAN++
